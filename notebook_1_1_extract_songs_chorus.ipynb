# %%
from utils import DownloadChorus
from lyricsgenius import Genius

# %%
genius = Genius('5uFFEjTRYVBuWxSwBW_Xy3J8hZfOInDZ9o6ttuW_YjBnSZlTFSWS66m0vwGiSXDm')

# %%
DownloadChorus.genius = genius

# %%
# Lista de artistas
artists = ["Kanye West", "Cardi B", "Lil Nas X", "Kelsea Ballerini", "Gabby Barrett", "Jason Aldean", "The Chainsmokers",
    "Marshmello", "Calvin Harris", "David Guetta", "Zedd", "Lorde", "Phoebe Bridgers",
    "Tame Impala", "Vampire Weekend", "Glass Animals", "Michael Bublé", "Josh Groban",
    "Rod Stewart", "Celine Dion", "Norah Jones"
]

# %%
DownloadChorus.download_choruses(artists)
# Out:
# Searching for songs by Justin Bieber...
#
# Song 1: "Love Yourself"
# Song 2: "Baby"
# Song 3: "Sorry"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Justin Bieber Love Yourself"...
# Done.
# Searching for "Justin Bieber Baby"...
# Done.
# Searching for "Justin Bieber Sorry"...
# Done.
# Searching for songs by Kendrick Lamar...
#
# Song 1: "HUMBLE."
# Song 2: "​m.A.A.d city"
# Song 3: "Swimming Pools (Drank)"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Kendrick Lamar HUMBLE."...
# Done.
# Searching for "Kendrick Lamar ​m.A.A.d city"...
# Done.
# Searching for "Kendrick Lamar Swimming Pools (Drank)"...
# Done.
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Se ha producido un error al intentar descargar el coro de Kanye West: Request timed out:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Cardi B...
#
# Se ha producido un error al intentar descargar el coro de Cardi B: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Lil Nas X...
#
# Se ha producido un error al intentar descargar el coro de Lil Nas X: Request timed out:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Nicki Minaj...
#
# Song 1: "Only"
# Song 2: "Feeling Myself"
# Song 3: "Barbie Dreams"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Nicki Minaj Only"...
# Done.
# Searching for "Nicki Minaj Feeling Myself"...
# Done.
# Searching for "Nicki Minaj Barbie Dreams"...
# Done.
# Searching for songs by Beyoncé...
#
# Song 1: "Drunk in Love"
# Song 2: "Formation"
# Song 3: "Partition"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Beyoncé Drunk in Love"...
# Done.
# Searching for "Beyoncé Formation"...
# Done.
# Searching for "Beyoncé Partition"...
# Done.
# Searching for songs by Rihanna...
#
# Song 1: "Work"
# Song 2: "Love on the Brain"
# Song 3: "Needed Me"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Rihanna Work"...
# Done.
# Searching for "Rihanna Love on the Brain"...
# Done.
# Searching for "Rihanna Needed Me"...
# Done.
# Searching for songs by Alicia Keys...
#
# Song 1: "If I Ain’t Got You"
# Song 2: "Girl On Fire"
# Song 3: "Empire State of Mind, Part II (Broken Down)"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Alicia Keys If I Ain’t Got You"...
# Done.
# Searching for "Alicia Keys Girl On Fire"...
# Done.
# Searching for "Alicia Keys Empire State of Mind, Part II (Broken Down)"...
# Done.
# Searching for songs by John Legend...
#
# Song 1: "All of Me"
# Song 2: "Ordinary People"
# Song 3: "You & I (Nobody in the World)"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "John Legend All of Me"...
# Done.
# Searching for "John Legend Ordinary People"...
# Done.
# Searching for "John Legend You & I (Nobody in the World)"...
# Done.
# Searching for songs by Khalid...
#
# Song 1: "Young Dumb & Broke"
# Song 2: "Location"
# Song 3: "Better"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Khalid Young Dumb & Broke"...
# Done.
# Searching for "Khalid Location"...
# Done.
# Searching for "Khalid Better"...
# Done.
# Searching for songs by H.E.R....
#
# Changing artist name to 'Bruno Mars'
# Song 1: "That’s What I Like"
# Song 2: "Finesse (Remix)"
# Song 3: "Versace on the Floor"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "H.E.R. That’s What I Like"...
# Done.
# Searching for "H.E.R. Finesse (Remix)"...
# Done.
# Searching for "H.E.R. Versace on the Floor"...
# Done.
# Searching for songs by SZA...
#
# Song 1: "Love Galore"
# Song 2: "The Weekend"
# Song 3: "Good Days"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "SZA Love Galore"...
# Done.
# Searching for "SZA The Weekend"...
# Done.
# Searching for "SZA Good Days"...
# Done.
# Searching for songs by Frank Ocean...
#
# Song 1: "Thinkin Bout You"
# Song 2: "Nights"
# Song 3: "Self Control"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Frank Ocean Thinkin Bout You"...
# Done.
# Searching for "Frank Ocean Nights"...
# Done.
# Searching for "Frank Ocean Self Control"...
# Done.
# Searching for songs by Chris Brown...
#
# Song 1: "Look at Me Now"
# Song 2: "No Guidance"
# Song 3: "Privacy"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Chris Brown Look at Me Now"...
# Done.
# Searching for "Chris Brown No Guidance"...
# Done.
# Searching for "Chris Brown Privacy"...
# Done.
# Searching for songs by Janelle Monáe...
#
# Song 1: "Q.U.E.E.N."
# Song 2: "PYNK"
# Song 3: "Make Me Feel"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Janelle Monáe Q.U.E.E.N."...
# Done.
# Searching for "Janelle Monáe PYNK"...
# Done.
# Searching for "Janelle Monáe Make Me Feel"...
# Done.
# Searching for songs by Luke Combs...
#
# Song 1: "Dive"
# Song 2: "Forever After All"
# Song 3: "Beautiful Crazy"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Luke Combs Dive"...
# Done.
# Searching for "Luke Combs Forever After All"...
# Done.
# Searching for "Luke Combs Beautiful Crazy"...
# Done.
# Searching for songs by Kane Brown...
#
# Song 1: "What Ifs"
# Song 2: "Heaven"
# Song 3: "Homesick"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Kane Brown What Ifs"...
# Done.
# Searching for "Kane Brown Heaven"...
# Done.
# Searching for "Kane Brown Homesick"...
# Done.
# Searching for songs by Kelsea Ballerini...
#
# Song 1: "​the other girl"
# Song 2: "Penthouse"
# Song 3: "Mountain With A View"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Kelsea Ballerini ​the other girl"...
# Done.
# Searching for "Kelsea Ballerini Penthouse"...
# Done.
# Searching for "Kelsea Ballerini Mountain With A View"...
# Done.
# Searching for songs by Gabby Barrett...
#
# Song 1: "I Hope"
# Song 2: "The Good Ones"
# Song 3: "I Hope (Remix)"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Gabby Barrett I Hope"...
# Done.
# Searching for "Gabby Barrett The Good Ones"...
# Done.
# Searching for "Gabby Barrett I Hope (Remix)"...
# Done.
# Searching for songs by Jason Aldean...
#
# Song 1: "Try That In A Small Town"
# Song 2: "You Make It Easy"
# Song 3: "Dirt Road Anthem"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Jason Aldean Try That In A Small Town"...
# Done.
# Searching for "Jason Aldean You Make It Easy"...
# Done.
# Searching for "Jason Aldean Dirt Road Anthem"...
# Done.
# Searching for songs by The Chainsmokers...
#
# Se ha producido un error al intentar descargar el coro de The Chainsmokers: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Marshmello...
#
# Song 1: "Silence"
# Song 2: "Alone"
# Song 3: "Keep It Mello"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Marshmello Silence"...
# Done.
# Searching for "Marshmello Alone"...
# Done.
# Searching for "Marshmello Keep It Mello"...
# Done.
# Searching for songs by Calvin Harris...
#
# Song 1: "Slide"
# Song 2: "Feels"
# Song 3: "Rollin"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Calvin Harris Slide"...
# Done.
# Searching for "Calvin Harris Feels"...
# Done.
# Searching for "Calvin Harris Rollin"...
# Done.
# Searching for songs by David Guetta...
#
# Song 1: "2U"
# Song 2: "Titanium"
# Song 3: "Hey Mama"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "David Guetta 2U"...
# Done.
# Searching for "David Guetta Titanium"...
# Done.
# Searching for "David Guetta Hey Mama"...
# Done.
# Searching for songs by Zedd...
#
# Se ha producido un error al intentar descargar el coro de Zedd: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Lorde...
#
# Se ha producido un error al intentar descargar el coro de Lorde: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Phoebe Bridgers...
#
# Song 1: "Moon Song"
# Song 2: "Motion Sickness"
# Song 3: "I Know the End"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Phoebe Bridgers Moon Song"...
# Done.
# Searching for "Phoebe Bridgers Motion Sickness"...
# Done.
# Searching for "Phoebe Bridgers I Know the End"...
# Done.
# Searching for songs by Tame Impala...
#
# Song 1: "The Less I Know the Better"
# Song 2: "New Person, Same Old Mistakes"
# Song 3: "Let It Happen"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Tame Impala The Less I Know the Better"...
# Done.
# Searching for "Tame Impala New Person, Same Old Mistakes"...
# Done.
# Searching for "Tame Impala Let It Happen"...
# Done.
# Searching for songs by Vampire Weekend...
#
# Song 1: "Step"
# Song 2: "Unbelievers"
# Song 3: "Oxford Comma"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Vampire Weekend Step"...
# Done.
# Searching for "Vampire Weekend Unbelievers"...
# Done.
# Searching for "Vampire Weekend Oxford Comma"...
# Done.
# Searching for songs by Glass Animals...
#
# Song 1: "Heat Waves"
# Song 2: "Gooey"
# Song 3: "The Other Side of Paradise"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Glass Animals Heat Waves"...
# Done.
# Searching for "Glass Animals Gooey"...
# Done.
# Searching for "Glass Animals The Other Side of Paradise"...
# Done.
# Searching for songs by Michael Bublé...
#
# Song 1: "L O V E"
# Song 2: "Haven’t Met You Yet"
# Song 3: "Feeling Good"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Michael Bublé L O V E"...
# Done.
# Searching for "Michael Bublé Haven’t Met You Yet"...
# Done.
# Searching for "Michael Bublé Feeling Good"...
# Done.
# Searching for songs by Josh Groban...
#
# Song 1: "You Raise Me Up"
# Song 2: "Evermore"
# Song 3: "Dust and Ashes"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Josh Groban You Raise Me Up"...
# Done.
# Searching for "Josh Groban Evermore"...
# Done.
# Searching for "Josh Groban Dust and Ashes"...
# Done.
# Searching for songs by Rod Stewart...
#
# Song 1: "Da Ya Think I’m Sexy?"
# Song 2: "I Don’t Want to Talk About It"
# Song 3: "Young Turks"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Rod Stewart Da Ya Think I’m Sexy?"...
# Done.
# Searching for "Rod Stewart I Don’t Want to Talk About It"...
# Done.
# Searching for "Rod Stewart Young Turks"...
# Done.
# Searching for songs by Celine Dion...
#
# Changing artist name to 'Céline Dion'
# Se ha producido un error al intentar descargar el coro de Celine Dion: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
# Searching for songs by Norah Jones...
#
# Song 1: "Don’t Know Why"
# Song 2: "Come Away With Me"
# Song 3: "Turn Me On"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for "Norah Jones Don’t Know Why"...
# Done.
# Searching for "Norah Jones Come Away With Me"...
# Done.
# Searching for "Norah Jones Turn Me On"...
# Done.
